# %%
import random

# %%
def newpos(pos, vel, index):
    pos[index] = pos[index] + vel[index]
    if pos[index] > road:
        pos[index] = pos[index] - 40
    return pos

# %%
def InitialCond(NCars, road):
    pos = zeros(NCars)
    vel = zeros(NCars)
    for i in range(len(pos)-1):
        pos[i] = randint(0, road)
    for k in range(len(vel)-1):
        vel[k] = randint(0, road)
    return pos, vel

# %%
def CA184(pos, vel, road, cars):
    pos = zeros(cars)
    vel = zeros(cars)
    for i in range(len(pos)-1):
        pos[i] = randint(0, road)
    for k in range(len(vel)-1):
        vel[k] = randint(0, road-cars)
    index = randint(0, len(pos)-1)
    carpos = pos[index]
    sortedpos = sort(pos)
    prob = random.randint(0, 1)
    if carpos == (len(pos)-1):
        gi = sortedpos[0]
        if gi == 0:
            vel[index] = 0
    else:
        gi = (sortedpos[index+1] - sortedpos[index])
        if gi == 0:
            vel[index] = 0
    if vel[index] > gi:
        vel[index] == gi
    elif vel[index] < gi and vel[index] < max(vel):
        vel[index] = vel[index] + 1
    else:
        vel[index] = vel[index]*prob
    newpos(pos, vel, index)
    print "CA184 Position is: " + str(pos[index])
    print "CA184 Velocity is: " + str(vel[index])
    print "CA184 Space between car and car before: " + str(gi)
    return pos[index], vel[index], gi

# %%
cars = 5
road = 40
Ncars  = 10
road = 40
pos, vel = InitialCond(Ncars, road)
CA184(pos, vel, road, cars)
# Out:
# CA184 Position is: 14.0
# CA184 Velocity is: 16.0
# CA184 Space between car and car before: 3.0
# (14.0, 16.0, 3.0)

# %%
N = 150
Ncars = 10
road = 40
posi = posi1 = posi2 = zeros(N)
veli = veli1 = veli2 = zeros(N)
g= g1 = g2 = zeros(N)
dens = dens1= dens2 = zeros(N)
avgveli = avgveli1 = avgveli2 = zeros(N)
curr = curr1 = curr2 = zeros(N)
conds = InitialCond(Ncars, road)
pos = pos1 = pos2= conds[0]
vel = vel1 = vel2 =conds[1]
for i in range(N-1):
    posi1[i], veli1[i], g1[i] = CA184(pos1, vel1, road, Ncars)
    dens1[i] = Ncars/(posi1[i])
    avgveli1[i] = average(veli1[i])
    curr1[i] = dens1[i]*avgveli1[i]
# Out:
# CA184 Position is: 28.0
# CA184 Velocity is: 0.0
# CA184 Space between car and car before: 0.0
# CA184 Position is: 34.0
# CA184 Velocity is: 12.0
# CA184 Space between car and car before: 4.0
# CA184 Position is: 26.0
# CA184 Velocity is: 9.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 2.0
# CA184 Velocity is: 19.0
# CA184 Space between car and car before: 3.0
# CA184 Position is: 18.0
# CA184 Velocity is: 29.0
# CA184 Space between car and car before: 13.0
# CA184 Position is: 9.0
# CA184 Velocity is: 0.0
# CA184 Space between car and car before: 0.0
# CA184 Position is: 7.0
# CA184 Velocity is: 16.0
# CA184 Space between car and car before: 3.0
# CA184 Position is: 22.0
# CA184 Velocity is: 7.0
# CA184 Space between car and car before: 3.0
# CA184 Position is: 13.0
# CA184 Velocity is: 12.0
# CA184 Space between car and car before: 4.0
# CA184 Position is: 20.0
# CA184 Velocity is: 4.0
# CA184 Space between car and car before: 7.0
# CA184 Position is: 0.0
# CA184 Velocity is: 0.0
# CA184 Space between car and car before: 0.0
# CA184 Position is: 36.0
# CA184 Velocity is: 17.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 17.0
# CA184 Velocity is: 6.0
# CA184 Space between car and car before: 5.0
# CA184 Position is: 14.0
# CA184 Velocity is: 11.0
# CA184 Space between car and car before: 5.0
# CA184 Position is: 8.0
# CA184 Velocity is: 6.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 1.0
# CA184 Velocity is: 12.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 14.0
# CA184 Velocity is: 27.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 35.0
# CA184 Velocity is: 0.0
# CA184 Space between car and car before: 0.0
# CA184 Position is: 14.0
# CA184 Velocity is: 29.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 7.0
# CA184 Velocity is: 24.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 8.0
# CA184 Velocity is: 0.0
# CA184 Space between car and car before: 6.0
# CA184 Position is: 18.0
# CA184 Velocity is: 15.0
# CA184 Space between car and car before: 16.0
# CA184 Position is: 22.0
# CA184 Velocity is: 1.0
# CA184 Space between car and car before: 1.0
# CA184 Position is:
0
# CA184 Velocity is: 4.0
# CA184 Space between car and car before: 3.0
# CA184 Position is: 8.0
# CA184 Velocity is: 7.0
# CA184 Space between car and car before: 11.0
# CA184 Position is: 19.0
# CA184 Velocity is: 13.0
# CA184 Space between car and car before: 6.0
# CA184 Position is: 29.0
# CA184 Velocity is: 27.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 22.0
# CA184 Velocity is: 17.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 16.0
# CA184 Velocity is: 12.0
# CA184 Space between car and car before: 8.0
# CA184 Position is: 30.0
# CA184 Velocity is: 6.0
# CA184 Space between car and car before: 3.0
# CA184 Position is: 30.0
# CA184 Velocity is: 20.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 32.0
# CA184 Velocity is: 0.0
# CA184 Space between car and car before: 0.0
# CA184 Position is: 4.0
# CA184 Velocity is: 7.0
# CA184 Space between car and car before: 4.0
# CA184 Position is: 16.0
# CA184 Velocity is: 21.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 30.0
# CA184 Velocity is: 6.0
# CA184 Space between car and car before: 3.0
# CA184 Position is: 13.0
# CA184 Velocity is: 19.0
# CA184 Space between car and car before: 4.0
# CA184 Position is: 9.0
# CA184 Velocity is: 11.0
# CA184 Space between car and car before: 4.0
# CA184 Position is: 2.0
# CA184 Velocity is: 2.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 7.0
# CA184 Velocity is: 4.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 12.0
# CA184 Velocity is: 25.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 32.0
# CA184 Velocity is: 3.0
# CA184 Space between car and car before: 7.0
# CA184 Position is: 39.0
# CA184 Velocity is: 23.0
# CA184 Space between car and car before: 3.0
# CA184 Position is: 8.0
# CA184 Velocity is: 3.0
# CA184 Space between car and car before: 10.0
# CA184 Position is: 11.0
# CA184 Velocity is: 10.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 11.0
# CA184 Velocity is: 27.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 1.0
# CA184 Velocity is: 24.0
# CA184 Space between car and car before: 7.0
# CA184 Position is: 1.0
# CA184 Velocity is: 18.0
# CA184 Space between car and car before: 4.0
# CA184 Position is: 30.0
# CA184 Velocity is: 15.0
# CA184 Space between car and car before: 9.0
# CA184 Position is: 5.0
# CA184 Velocity is: 14.0
# CA184 Space between car and car before: 9.0
# CA184 Position is: 9.0
# CA184 Velocity is: 0.0
# CA184 Space between car and car before: 0.0
# CA184 Position is: 11.0
# CA184 Velocity is: 6.0
# CA184 Space between car and car before: 5.0
# CA184 Position is: 17.0
# CA184 Velocity is: 16.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 10.0
# CA184 Velocity is: 19.0
# CA184 Space between car and car before: 6.0
# CA184 Position is: 18.0
# CA184 Velocity is: 12.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 22.0
# CA184 Velocity is: 17.0
# CA184 Space between car and car before: 5.0
# CA184 Position is: 14.0
# CA184 Velocity is: 16.0
# CA184 Space between car and car before: 14.0
# CA184 Position is: 26.0
# CA184 Velocity is: 29.0
# CA184 Space between car and car before: 9.0
# CA184 Position is: 27.0
# CA184 Velocity is: 29.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 2.0
# CA184 Velocity is: 0.0
# CA184 Space between car and car before: 0.0
# CA184 Position is: 31.0
# CA184 Velocity is: 3.0
# CA184 Space between car and car before: 3.0
# CA184 Position is: 21.0
# CA184 Velocity is: 22.0
# CA184 Space between car and car before: 12.0
# CA184 Position is: 40.0
# CA184 Velocity is: 18.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 35.0
# CA184 Velocity is: 12.0
# CA184 Space between car and car before: 16.0
# CA184 Position is: 1.0
# CA184 Velocity is: 9.0
# CA184 Space between car and car before: 4.0
# CA184 Position is: 38.0
# CA184 Velocity is: 3.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 17.0
# CA184 Velocity is: 4.0
# CA184 Space between car and car before: 7.0
# CA184 Position is: 29.0
# CA184 Velocity is: 4.0
# CA184 Space between car and car before: 4.0
# CA184 Position is: 13.0
# CA184 Velocity is: 28.0
# CA184 Space between car and car before: 2.0
# CA184 Position is: 13.0
# CA184 Velocity is: 7.0
# CA184 Space between car and car before: 7.0
# CA184 Position is: 22.0
# CA184 Velocity is: 28.0
# CA184 Space between car and car before: 8.0
# CA184 Position is: 19.0
# CA184 Velocity is: 28.0
# CA184 Space between car and car before: 3.0
# CA184 Position is: 9.0
# CA184 Velocity is: 4.0
# CA184 Space between car and car before: 1.0
# CA184 Position is: 20.0
# CA184 Velocity is: 25.0
# CA184 Space between car and car before: 3.0
# -c:15: RuntimeWarning: divide by zero encountered in double_scalars
# -c:17: RuntimeWarning: invalid value encountered in double_scalars

# %%
t = arange(0, 150)
plot(t, posi)
show()

# %%
plot(t, curr)
show()

# %%
plot(dens, posi, '*')
show()
