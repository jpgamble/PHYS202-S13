# %% [markdown]
# STCA Ruleset For One-Dimensional Traffic Flow
# =
# The following shows an attempt at programming the STCA Ruleset or "Stochastic Trac Cellular Automata"
# -
# The rules are as follows:
#
# 1. Let $g_i$ equal the number of empty sites in front of each car.
#
# 2. If $g_i$ = 0, that car does not move during this time step.
#
# 3. If $v_i$ > $g_i$, slow down to $v_i = g_i$
#
# 4. If $v_i$ < $g_i$ and $v_i$ < vmax, speed up by one unit: $v_i = v_i + 1$.
#
# 5. For $v_i$ > 0, allow for random slowdowns by letting $v_i = v_i - 1$ with probability p.
#
# 6. Move all cars forward by $v_i$
# .

# %%
import random #This allows for the definition of a random element to be added to the ruleset

# %% [markdown]
# Below are three definitions of functions.
# -
#
# In these functions we allow the movement of the traffic elements $(newpos)$ and a definition of the initial conditions $(InitialCond)$ for the ruleset $(STCA)$ to take place.

# %%
def newpos(pos, vel, index):
    """Takes the parameters of position and velocity and pushes the new values to the array them for their movement based on their individual index."""
    pos[index] = pos[index] + vel[index] # moves each element 
    if pos[index] > road: #moves the element according to the offset of the road
        pos[index] = pos[index] - 40
    return pos

# %%
def InitialCond(NCars, road):
    """Takes Number of Cars (NCARS) and Maximum Road Length as parameters, returning a position and velocity array for each element"""
    pos = zeros(NCars)
    vel = zeros(NCars)
    for i in range(len(pos)-1):
        pos[i] = randint(0, road)#fills the position array with values between 0 and the maximum road length
    for k in range(len(vel)-1):
        vel[k] = randint(0, road)# Fills velecoty array with values between 0 and max number of availible spaces
    return pos, vel

# %%
def STCA(pos, vel, road, cars):
    """Implements the ruleset on the given parameters of Position and Velocity array, road length and number of cars"""
    for i in range(len(pos)-1):
        pos[i] = randint(0, road)#pushes new values into the position array
    for k in range(len(vel)-1):
        vel[k] = randint(0, road-cars)#pushes the new values into the velcoty array
    prob = rand(1) #sets the probablity of slowdown
    index = randint(0, len(pos)-1)
    carpos = pos[index]#choses a random car
    sortedpos = sort(pos)#sorts the positions to find the space between the chosen car and its surrounding constitutants 
    if carpos == (len(pos)-1): #this states that if the element is in the last possible position it space is equal to the space before the first element in the array
        gi = sortedpos[0]
        if gi == 0:
            vel[index] = 0
    else:
        #Rule 1
        gi = (sortedpos[index+1] - sortedpos[index])
        #Rule 2
        if gi == 0:
            vel[index] = 0
    #Rule 3
    if vel[index] > gi:
        vel[index] == gi
    #Rule 4
    elif vel[index] < gi and vel[index] < max(vel):
        vel[index] = vel[index] + 1
    #Rule 5
    else:
        vel[index] = vel[index]*prob
        for e in range(cars):
            pos[e] = pos[e]+vel[e] # Adjusts the All positions according to velocity
    print "STCA Position is: " + str(pos[index])
    print "STCA Velocity is: " + str(vel[index])
    print "STCA Space between car and car before: " + str(gi)
    return pos[index], vel[index], gi #returns the value for interpretation

# %% [markdown]
# With the functions defined, interpretation of the data is the next step.
# -
# Below I have defined the initial conditions and set the basis for the arrays to be analyzed.

# %%
N = 150 #Sets number of time steps we are going to look at
Ncars = 10#Sets the number of cars
road = 40#sets the road length
posi2 = zeros(N)
veli2 = zeros(N)
g2 = zeros(N)
dens2 = zeros(N)
avgveli2 = zeros(N)
curr2 = zeros(N)
conds = InitialCond(Ncars, road)#sets the initial conditions for analysis
pos2= conds[0] 
#because InitialCond returns a tuple the position array will be filled with the first coloumn of values 
#and velocity array will be filled with the second coloumn of elements 
vel2 =conds[1]
for i in range(N-1):
    posi2[i], veli2[i], g2[i] = STCA(pos2, vel2, road, Ncars)
    dens2[i] = Ncars/(posi2[i])#the density is defined as Number of cars per position
    avgveli2[i] = average(veli2[i])
    curr2[i] = dens2[i]*avgveli2[i]
# Out:
# STCA Position is: 34.0
# STCA Velocity is: 7.0
# STCA Space between car and car before: 14.0
# STCA Position is: 13.0
# STCA Velocity is: 1.0
# STCA Space between car and car before: 7.0
# STCA Position is: 0.0
# STCA Velocity is: 21.0
# STCA Space between car and car before: 9.0
# STCA Position is: 7.0
# STCA Velocity is: 15.0
# STCA Space between car and car before: 6.0
# STCA Position is: 8.0
# STCA Velocity is: 24.0
# STCA Space between car and car before: 2.0
# STCA Position is: 35.0
# STCA Velocity is: 3.0
# STCA Space between car and car before: 3.0
# STCA Position is: 35.0
# STCA Velocity is: 3.0
# STCA Space between car and car before: 9.0
# STCA Position is: 24.0
# STCA Velocity is: 8.0
# STCA Space between car and car before: 3.0
# STCA Position is: 11.0
# STCA Velocity is: 1.0
# STCA Space between car and car before: 5.0
# STCA Position is: 30.0
# STCA Velocity is: 9.0
# STCA Space between car and car before: 4.0
# STCA Position is: 3.0
# STCA Velocity is: 15.0
# STCA Space between car and car before: 2.0
# STCA Position is: 17.0
# STCA Velocity is: 17.0
# STCA Space between car and car before: 1.0
# STCA Position is: 12.0
# STCA Velocity is: 15.0
# STCA Space between car and car before: 1.0
# STCA Position is: 33.0
# STCA Velocity is: 5.0
# STCA Space between car and car before: 1.0
# STCA Position is: 18.0
# STCA Velocity is: 7.0
# STCA Space between car and car before: 2.0
# STCA Position is: 1.46941898922
# STCA Velocity is: 1.46941898922
# STCA Space between car and car before: 2.0
# STCA Position is: 6.0
# STCA Velocity is: 0.0
# STCA Space between car and car before: 0.0
# STCA Position is: 3.0
# STCA Velocity is: 13.0
# STCA Space between car and car before: 1.0
# STCA Position is: 10.0
# STCA Velocity is: 0.0
# STCA Space between car and car before: 0.0
# STCA Position is: 28.0
# STCA Velocity is: 23.0
# STCA Space between car and car before: 5.0
# STCA Position is: 38.0
# STCA Velocity is: 0.0
# STCA Space between car and car before: 0.0
# STCA Position is: 2.0
# STCA Velocity is: 18.0
# STCA Space between car and car before: 7.0
# STCA Position is: 21.0
# STCA Velocity is: 6.0
# STCA Space between car and car before: 3.0
# STCA Position is: 0.0
# STCA Velocity is: 0.0
# STCA Space between car and car before: 0.0
# STCA Position is: 26.0
# STCA Velocity is: 17.0
# STCA Space between car and car before: 1.0
# STCA Position is: 15.0
# STCA Velocity is: 0.0
# STCA Space between car and car before: 0.0
# STCA Position is: 39.0
# STCA Velocity is: 29.0
# STCA Space between car and car before: 2.0
# STCA Position is: 24.0
# STCA Velocity is: 16.0
# STCA Space between car and car before: 10.0
# STCA Position is: 38.0
# STCA Velocity is: 14.0
# STCA Space between car and car before: 2.0
# STCA Position is: 25.0
# STCA Velocity is: 3.0
# STCA Space between car and car before: 1.0
# STCA Position is: 15.0
# STCA Velocity is: 23.0
# STCA Space between car and car before: 2.0
# STCA Position is: 25.0
# STCA Velocity is: 15.0
# STCA Space between car and car before: 5.0
# STCA Position is: 24.0
# STCA Velocity is: 4.0
# STCA Space between car and car before: 6.0
# STCA Position is: 14.0
# STCA Velocity is: 28.0
# STCA Space between car and car before: 11.0
# STCA Position is: 7.0
# STCA Velocity is: 9.0
# STCA Space between car and car before: 4.0
# STCA Position is: 5.0
# STCA Velocity is: 29.0
# STCA Space between car and car before: 3.0
# STCA Position is: 37.0
# STCA Velocity is: 15.0
# STCA Space between car and car before:
0
# STCA Velocity is: 0.0
# STCA Space between car and car before: 0.0
# STCA Position is: 32.0
# STCA Velocity is: 9.0
# STCA Space between car and car before: 3.0
# STCA Position is: 16.0
# STCA Velocity is: 13.0
# STCA Space between car and car before: 1.0
# STCA Position is: 9.0
# STCA Velocity is: 0.0
# STCA Space between car and car before: 0.0
# STCA Position is: 14.0
# STCA Velocity is: 5.0
# STCA Space between car and car before: 2.0
# STCA Position is: 8.96425006898
# STCA Velocity is: 2.96425006898
# STCA Space between car and car before: 5.0
# STCA Position is: 25.0
# STCA Velocity is: 20.0
# STCA Space between car and car before: 5.0
# STCA Position is: 0.0
# STCA Velocity is: 28.0
# STCA Space between car and car before: 3.0
# STCA Position is: 36.0
# STCA Velocity is: 8.0
# STCA Space between car and car before: 1.0
# STCA Position is: 2.0
# STCA Velocity is: 29.0
# STCA Space between car and car before: 1.0
# STCA Position is: 12.0
# STCA Velocity is: 18.0
# STCA Space between car and car before: 8.0
# STCA Position is: 34.0
# STCA Velocity is: 20.0
# STCA Space between car and car before: 6.0
# STCA Position is: 24.0
# STCA Velocity is: 24.0
# STCA Space between car and car before: 5.0
# STCA Position is: 20.0
# STCA Velocity is: 28.0
# STCA Space between car and car before: 1.0
# STCA Position is: 10.0
# STCA Velocity is: 3.0
# STCA Space between car and car before: 11.0
# STCA Position is: 15.0
# STCA Velocity is: 11.0
# STCA Space between car and car before: 1.0
# STCA Position is: 1.0
# STCA Velocity is: 0.0
# STCA Space between car and car before: 0.0
# STCA Position is: 10.0
# STCA Velocity is: 28.0
# STCA Space between car and car before: 4.0
# -c:17: RuntimeWarning: divide by zero encountered in double_scalars
# -c:19: RuntimeWarning: invalid value encountered in double_scalars

# %%
t = arange(0, 150)
xlim(0,150)
plot(t, posi2)
show()

# %% [markdown]
# Upon analysis of the graph above (Position per time) and assuming that the element is constrained to not being able to teleport, the movement of the chosen element appears to be very sporadic which is most likely inherit to the chosing of the random index in the position array and the probability of slowdown.

# %%
plot(t, curr2)
show()

# %% [markdown]
# The increase in current takes place at largest changes in position due to the direct relationship between current and average velocity as well as the probability of slowdown occurances.

# %%
plot(dens2, posi2, '*') 
show()

# %% [markdown]
# Above we witness a smooth exponential decay of position per density, showing the collection of elements at the smaller velocities. Which seems very inherit to the collective movement of all the elements in each run.

# %%
from matplotlib import animation
import sys
cars = 5
road = 40
x = np.linspace(0, road, 1000)
pos, vel = InitialCond(cars, road)
sys.path.insert(0,"/c/Users/Jacob/JSAnimation")
fig = plt.figure()
ax = plt.axes(xlim=(0, road), ylim=(0, cars))
line, = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data((x), posi2)
    return line,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=100, interval=20, blit=True)
show()
