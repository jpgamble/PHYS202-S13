# %% [markdown]
# Number letter counts
# =
# Problem 17
# -
# If the numbers 1 to 5 are written out in words: one, two, three, four, five, then there are 3 + 3 + 5 + 4 + 4 = 19 letters used in total.
#
# If all the numbers from 1 to 1000 (one thousand) inclusive were written out in words, how many letters would be used?
#
#
# NOTE: Do not count spaces or hyphens. For example, 342 (three hundred and forty-two) contains 23 letters and 115 (one hundred and fifteen) contains 20 letters. The use of "and" when writing out numbers is in compliance with British usage.

# %%
def counter1_10(i):
    k = 0
    while i < 10:
        if i == 0 or i == 9:
            k += 4
        elif i == 1 or i ==2 or i == 10:
            k += 3
        elif i>2 and i<8:
            k += 5

# %%
def counter(i):
    k = 0
    L= []
    P = []
    one_to_20 = ["zero", "one","two","three","four","five","six","seven","eight","nine","ten","eleven","twelve","thirteen","fourteen","fifteen","sixteen","seventeen","eighteen","nineteen"] 
    tens_place = ["ten","twenty","thirty","fourty","fifty","sixty","seventy","eighty","ninety"]  
    hundreds =["onehundred","twohundred","threehundred","fourhundred","fivehundred","sixhundred","sevenhundred","eighthundred","ninehundred"]
    if len(str(i))<3 and i<20:
        L.append(str(one_to_20[i]))
        for d in range(len(L)-1):
            k += 1
        print k
    elif len(str(i))<3 and 100>i>20:
        P.append(str(i))
        L.append(str(tens_place[(P[0])]))
        L.append(str(one_to_20[(P[1])]))
        for d in range(len(L)-1):
            k += 1
        print k
    else:
        P.append(int(str(i))) 
        L.append(str(tens_place[(P[0])]))
        L.append(str(one_to_20[(P[1])]))
        L.append(str(hundreds[(P[2])]))
        for d in range(len(L)-1):
            k += 1
        print k

# %%
def counter2(i):
    k = 0
    L= []
    P = []
    one_to_20 = ["zero", "one","two","three","four","five","six","seven","eight","nine","ten","eleven","twelve","thirteen","fourteen","fifteen","sixteen","seventeen","eighteen","nineteen"] 
    tens_place = ["ten","twenty","thirty","fourty","fifty","sixty","seventy","eighty","ninety"]  
    hundreds =["onehundred","twohundred","threehundred","fourhundred","fivehundred","sixhundred","sevenhundred","eighthundred","ninehundred"]
    if i<20:
        for r in str((i)):
            P.append(int(r))
        k = len(str(one_to_20[(P[0])]))
        return k
    elif 100>i>=20:
        for r in str((i)):
            P.append(int(r))
            print P
        k = int(len(str(tens_place[(P[0])]))+ len(str(one_to_20[(P[1])])))
        return k
    elif i>=100:
        for r in str(i):
            P.append(int(r))
            print P
        k = len(str(tens_place[(P[0])]))+len(str(one_to_20[(P[1])]))+ len(str(hundreds[(P[2])]))
        return k

# %%
print int(len(str('one')))
# Out:
# 3

# %%
f = 0
for E in range(100):
    f += counter2(E)
#print f
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-fa59408deaca> in <module>()
#       1 f = 0
#       2 for E in range(100):
# ----> 3     f += counter2(E)
#       4 #print f
#
# <ipython-input-73-524e595b1126> in counter2(i)
#      15             P.append(int(r))
#      16             print P
# ---> 17         k = int(len(str(tens_place[(P[0])]))+ len(str(one_to_20[(P[1])])))
#      18         return k
#      19     elif i>=100:
#
# IndexError: list index out of range
# [2]
# [2, 0]
# [2]
# [2, 1]
# [2]
# [2, 2]
# [2]
# [2, 3]
# [2]
# [2, 4]
# [2]
# [2, 5]
# [2]
# [2, 6]
# [2]
# [2, 7]
# [2]
# [2, 8]
# [2]
# [2, 9]
# [3]
# [3, 0]
# [3]
# [3, 1]
# [3]
# [3, 2]
# [3]
# [3, 3]
# [3]
# [3, 4]
# [3]
# [3, 5]
# [3]
# [3, 6]
# [3]
# [3, 7]
# [3]
# [3, 8]
# [3]
# [3, 9]
# [4]
# [4, 0]
# [4]
# [4, 1]
# [4]
# [4, 2]
# [4]
# [4, 3]
# [4]
# [4, 4]
# [4]
# [4, 5]
# [4]
# ...
