# %% [markdown]
# Monte Carlo Integration
# =

# %%
l = w= 4
r= 1.375
Nin = 15
N= 40
Aboard = l*w
Aexact = pi*r**2
Acirc = (Nin/float(N))*Aboard
print "Aboard = ", Aboard
print "Aexact=", Aexact
print"Acic=", Acirc
print "Error=", (100.*(Acirc-Aexact)/Aexact),"%"
# Out:
# Aboard =  16
# Aexact= 5.93957361069
# Acic= 6.0
# Error= 1.01735230957 %

# %% [markdown]
# Example 1
# -

# %%
f= lambda x: x**(.5)+ sin(x)

# %%
x = arange(0., 15., 0.001)

# %%
myplot = plot(x, f(x), lw = w)
ylabel(r'$x^{1/2} + \sin(x)$', fontsize = 20)
xlabel(r'$x$', fontsize = 20)
xlim(0., 15.)
show()

# %%
xmin= 1.7
xmax = 12.4

subx = x[logical_and((x>xmin), (x<xmax))]
ymax = max(f(subx))*1.05
ymin = 0

myplot = plot(x, f(x), lw=3)
xlim(0., 15.)

plot([xmin, xmin], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmax, xmax], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmin, xmax], [ymax, ymax], color = 'k', linestyle = '--')

# %%
N = 10000
samples_x = xmin + (xmax - xmin)*random_sample(N);
samples_y  = ymin + (ymax-ymin)*random_sample(N);

myplot = plot(x, f(x), lw=3)
xlim(0., 15.)

plot(samples_x[1:200], samples_y[1:200], '.')

plot([xmin, xmin], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmax, xmax], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmin, xmax], [ymax, ymax], color = 'k', linestyle = '--')
show()

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6228

# %%
myplot = plot(x, f(x), lw= 3)
xlim(0., 15.)
plot(samples_x[1:200], samples_y[1:200], '.')
plot(samples_x[newmask[:200]], samples_y[newmask[:200]], '.')

plot([xmin, xmin], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmax, xmax], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmin, xmax], [ymax, ymax], color = 'k', linestyle = '--')
show()

# %%
I = (xmax - xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.7170736244

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax) - Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print "I_exact = ", Iexact
print "I_hitormiss", I
print "Error on I =", Ierr, '%'
# Out:
# I_exact =  26.5172145362
# I_hitormiss 26.7170736244
# Error on I = -0.753695633855 %

# %% [markdown]
# Ex 1 with '$x^{1/2}+ \sin{x}$'
# =

# %%
f= lambda x: x**(.5)+ sin(x)
xmin= 1.7
xmax = 12.4

subx = x[logical_and((x>xmin), (x<xmax))]
ymax = max(f(subx))*1.05
ymin = 0

N = 100000
samples_x = xmin + (xmax - xmin)*random_sample(N);
samples_y  = ymin + (ymax-ymin)*random_sample(N);

myplot = plot(x, f(x), lw=3)
xlim(0., 15.)
newmask = (samples_y < f(samples_x))

plot(samples_x[1:], samples_y[1:], '.')

plot([xmin, xmin], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmax, xmax], [ymin, ymax], color = 'k', linestyle = '--')
plot([xmin, xmax], [ymax, ymax], color = 'k', linestyle = '--')
show()

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
I = (xmax - xmin)*(ymax-ymin)*sum(newmask)/newmask.size
Iexact = Iana(xmax) - Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print "I_exact = ", Iexact
print "I_hitormiss", I
print "Error on I =", Ierr, '%'
# Out:
# I_exact =  26.5172145362
# I_hitormiss 26.498292193
# Error on I = 0.071358713821 %

# %% [markdown]
# Ex 2
# -
# a)Write the code to compute the integral of the function $f(x) = x^{1/2} + \sin{x}$ for ex 1 using the N = 10000
#
#
# b) Plot the function and the average value of the funtion for these samples on the same graph. The area under the aver is approximately equal to the area under the curve.
#
#
# c) Compute the percent difference between the integral using the ample mean method and the exact value. How does the sameple m,ean meathod result compare to the hit or miss method.

# %%
#a) 
N = 10000
x = xmin + (xmax - xmin)*random_sample(N)
N = 10000
Sig = 0
for i in range(N):
    Sig += f(x[i])
I = (Sig*(xmax- xmin))/N
print I
f= lambda x: x**(.5)+ sin(x)
x = xmin + (xmax - xmin)*random_sample(N)
plot(x, f(x),'r.', x, Sig*(x)/N)
show()
# Out:
# 26.5121369044

# %%
f= lambda x: x**(.5)+ sin(x)
x = xmin + (xmax - xmin)*random_sample(N)
plot(x, f(x), "r.")
show()

# %%
#c)
N = 10000
x = xmin + (xmax - xmin)*random_sample(N)
N = 10000
Sig = 0
for i in range(N):
    Sig += f(x[i])
I = (Sig*(x))/N
IntExact = x**(1.5) + cos(x)
PercentError = 100*abs(I - IntExact)/IntExact
print PercentError
# Out:
# [ 12.30087528   3.16228032  11.85804685 ...,  10.98745692  30.85156132
#   63.68222598]

# %% [markdown]
# Example 2
# =

# %%
fxyz = lambda x, y, z: sqrt(x**2 + y**2+z**2)
N = 1e6
L = 1.; W = 1.; H = 1.
x = L*random_sample(N); y = random_sample(N); z = H*random_sample(N)

IntMc = (L*W*H/N)*sum(fxyz(x,y,z))

# %%
N = 10000
fsph = lambda r, phi: (cos(phi)/r**3)

phiMax = 2*pi; thetaMax = pi; rMax = 1;
phi = phiMax*random_sample(N);
theta = thetaMax*random_sample(N);
r = rMax*random_sample(N);
Integral_MC = (phiMax*thetaMax*rMax/N)*sum(fsph(r, phi)*r**2*sin(theta))

# %% [markdown]
# Exercise 3
# =

# %%
import sys
sys.path.insert(0, '../Week4/')
from Electrostatics import *

sigma = 1e-6; #charge density
N = 1e6;
x0 = 2.; # P(x0, y0)
y0 = 3.;
xi = -1. + 2.001*random_sample(N); #-1<x<1 integration limits, make sure it is incline
yi = 0. + 2.001*random_sample(N); #0<y<2 integration limits

#electric potiential at P from a chunk of charge at xi , yi
Vi  = pointPotential(x0, y0, sigma, xi, yi);
Vtot = (2.*2./N)*sum(Vi)
print Vtot
# Out:
# 13026.5786116

# %%
import sys
sys.path.insert(0, '../Week4/')
from Electrostatics import *

sigma = 1e-6; #charge density
N = 1e6;
x0 = 2.; # P(x0, y0)
y0 = 3.;
ri = 0. + .012001*random_sample(N); #0<r<.012 integration limits, make sure it is incline
oi = 0. + ((2*pi)+.001)*random_sample(N); #0<o<2pi integration limits

#electric potiential at P from a chunk of charge at ri , oi
Vi  = pointPotential(x0, y0, sigma, ri, oi);
Vtot = (.012*2.*pi/N)*sum(Vi)
print Vtot
# Out:
# 266.489378162
